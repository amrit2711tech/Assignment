# %% [markdown]
# <a href="https://colab.research.google.com/github/amrit2711tech/Assignment/blob/main/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Iris** **Classification** **Visualization** **Assignment**

# %% [markdown]
# ###**Objective:**
#  The goal of this assignment is to help you understand data visualization using the Iris dataset. You
#  will explore how to use Matplotlib and Seaborn to create plots that reveal patterns in the data. This
#  exercise will also reinforce your understanding of data distributions, relationships, and class
#  separation in the dataset.

# %% [markdown]
# ###**Instructions**
#
# Use Matplotlib and Seaborn for plotting. Submit both your code and the plots. Clearly label your
#  plots

# %% [markdown]
# ###**Assignment** **Questions:**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv("https://raw.githubusercontent.com/amrit2711tech/Assignment/refs/heads/main/Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Use Seaborn to plot a pairplot of the dataset, showing different species in different colors
sns.pairplot(iris, hue="species",palette='Set1')
plt.suptitle("Pairplot of Iris Dataset by Species", y=1.02)
plt.show()

# %%
#Create a boxplot for each numerical feature (sepal length, sepal width, petal length, petal width)
 #categorized by species
sns.set(style="whitegrid")
features = ["sepal_length", "sepal_width", "petal_length", "petal_width"]
plt.figure(figsize=(12, 10))
for i, feature in enumerate(features):
    plt.subplot(2, 2, i+1)
    sns.boxplot(x="species", y=feature, data=iris, palette='Set2')
    plt.xlabel("Species")
    plt.ylabel(feature.capitalize())
    plt.title(f"Boxplot of {feature} by Species")
plt.tight_layout()
plt.suptitle("Boxplots of Iris Features by Species",fontsize=16,y=1.03)
plt.show()
# Out:
# /tmp/ipython-input-16-129407620.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="species", y=feature, data=iris, palette='Set2')
# /tmp/ipython-input-16-129407620.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="species", y=feature, data=iris, palette='Set2')
# /tmp/ipython-input-16-129407620.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="species", y=feature, data=iris, palette='Set2')
# /tmp/ipython-input-16-129407620.py:8: FutureWarning:
#
# ...

# %%
# Plot a violin plot for the 'petal length' feature grouped by species
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.violinplot(x="species", y="petal_length", data=iris, palette='Set3')
plt.xlabel("Species")
plt.ylabel("Petal Length (cm)")
plt.title("Violin Plot of Petal Length by Species")
plt.show()
# Out:
# /tmp/ipython-input-19-142731499.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="species", y="petal_length", data=iris, palette='Set3')

# %%
# Create a scatter plot using Matplotlib to visualize petal length vs petal width, coloring points by
#species
plt.figure(figsize=(8, 6))
sns.scatterplot(x="petal_length", y="petal_width", hue="species", data=iris, palette='Set2')
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.title("Scatter Plot of Petal Length vs Petal Width by Species")
plt.show()

# %%
#Draw a histogram to show the distribution of sepal lengths for all species combined
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.histplot(data=iris, x="sepal_length", hue="species",bins=15,color='orchid',kde=False)
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.title("Histogram of Sepal Lengths for All Species")
plt.show()

# %%
#Plot a heatmap of the correlation matrix for all numerical features in the Iris dataset
correlation_matrix = iris.drop('species',axis=1).corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm",linewidths=0.5, fmt=".2f")
plt.title("Heatmap of Correlation Matrix (Iris Dataset)")
plt.show()

# %%
# Based on your visualizations, describe how well the classes (species) are separated
#Pairplot for visual separation
sns.pairplot(iris, hue="species",palette='Set1')
plt.suptitle("Pairplot of Iris Dataset by Species", y=1.02)
plt.show()
#violin plot for the 'petal length'
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.violinplot(x="species", y="petal_length", data=iris, palette='Set3')
plt.xlabel("Species")
plt.ylabel("Petal Length (cm)")
plt.title("Violin Plot of Petal Length by Species")
plt.show()
#scatter plot:petal length vs petal width
plt.figure(figsize=(8, 6))
sns.scatterplot(x="petal_length", y="petal_width", hue="species", data=iris, palette='Set2')
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.title("Scatter Plot of Petal Length vs Petal Width by Species")
plt.show()
#heatmap of the correlation matrix
correlation_matrix = iris.drop('species',axis=1).corr()
plt.figure(figsize=(6,4))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm",linewidths=0.5, fmt=".2f")
plt.title("Heatmap of Correlation Matrix (Iris Dataset)")
plt.show()
# Text-based interpretation
print("\nInterpretation:")
print("- Setosa is clearly separable from the other two species in all plots, especially using petal features.")
print("- Versicolor and Virginica show some overlap, but still have distinguishable patterns in petal dimensions.")
print("- Petal length and petal width are highly correlated and most effective for species classification.")
print("- Sepal features are less useful for distinguishing Versicolor and Virginica.")
# Out:
# /tmp/ipython-input-29-1175622750.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="species", y="petal_length", data=iris, palette='Set3')
# Interpretation:
# - Setosa is clearly separable from the other two species in all plots, especially using petal features.
# - Versicolor and Virginica show some overlap, but still have distinguishable patterns in petal dimensions.
# - Petal length and petal width are highly correlated and most effective for species classification.
# - Sepal features are less useful for distinguishing Versicolor and Virginica.

# %%
#Write a short interpretation of which features are most useful
#for distinguishing between species.
print("Interpretation of Feature Importance for Species Separation:\n")
print("- Petal Length and Petal Width are the most effective features to distinguish between species.")
print("- Setosa is easily separable based on Petal Length and Width — very low values compared to others.")
print("- Versicolor and Virginica show some overlap, but Petal features still help in partial separation.")
print("- Sepal Length and Sepal Width show less distinction, especially between Versicolor and Virginica.")
print("\nConclusion: Petal Length and Petal Width are the most informative features for classification.")
# Out:
# Interpretation of Feature Importance for Species Separation:
#
# - Petal Length and Petal Width are the most effective features to distinguish between species.
# - Setosa is easily separable based on Petal Length and Width — very low values compared to others.
# - Versicolor and Virginica show some overlap, but Petal features still help in partial separation.
# - Sepal Length and Sepal Width show less distinction, especially between Versicolor and Virginica.
#
# Conclusion: Petal Length and Petal Width are the most informative features for classification.
